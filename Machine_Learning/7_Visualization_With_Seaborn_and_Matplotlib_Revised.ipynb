# %% [markdown]
# # **Introduction to  Data Visualization**📈

# %% [markdown]
# "_A picture is worth a thousand words" means that a single image can often convey a complex idea or story more effectively than a lengthy written description, implying that visuals can be more impactful than words alone._"

# %% [markdown]
# ![global-trends-data-visualization.png.webp](data:image/webp;base64,...)
#
# [source](https://www.justinmind.com/wp-content/webp-express/webp-images/uploads/2024/06/global-trends-data-visualization.png.webp)

# %% [markdown]
# Data visualization is the graphical representation of data and information. It helps to identify patterns, trends, and insights by presenting data in a visual format such as charts, graphs, and maps.

# %% [markdown]
# Data visualization is important in the following ways...
#
# ✅ Makes complex data easier to understand.
#
# ✅ Identifies patterns, trends, and correlations.
#
# ✅ Enhances decision-making with insights.
#
# ✅ Communicates results effectively to  viewers or business stakeholders.
#
# ✅ Aids exploratory data analysis (EDA) before modeling.

# %% [markdown]
# **What Makes A Good Visualization?**

# %% [markdown]
# For a good visual should...
#
# 🔹Avoid clutter and excessive information.
#
# 🔹 Tell a story that is, should convey a clear message.
#
# 🔹 Use the right type of chart that is, choose appropriate visuals for the data type.
#
# 🔹 Be aesthetically pleasing that is, make good use of colors, spacing, and labels.
#
# 🔹 Be accessible and intuitive that is, easy to interpret by the viewer.

# %% [markdown]
# **What To Note When Creating Visuals**
#
# 📌 Avoid using misleading scales or colors.
#
# 📌 Avoid choosing the wrong visualization for the data.
#
# 📌 Avoid colorblind-friendly palettes(especially for heatmaps)
#
# 📌 Label axes and legends properly.
#
# 📌 For subplots and multiple visuals maintain a clean layout with minimal distractions.
#
# 📌 Ensure to use consistent color schemes.

# %% [markdown]
# **Types Of Visuals  And Their Usecases**

# %% [markdown]
# 1. **Line Plot**: This is used to show trends or changes over time. You can use it if you want to track changes.
#
# 2. **Bar Plot**: This is used to compare quantities between categories.
#
# 3. **Scatter Plot**: To show relationship between two variables.
# 4. **Histogram**: To show the distribution of your data.
#
# 5. **Piechart**: To show proportions or percentages of a whole.
# 6. **Boxplot**: Primarily for detecting outliers, show distribution and the spread of your data.
#
# 7. **Heatmap**: This is used for correlation, showing the relationships between your data variables through colour intensity.

# %% [markdown]
# | **Data Type**               | **Best Charts**                               | **Best Library to Use**        |
# |-----------------------------|-----------------------------------------------|--------------------------------|
# | **Trends over time**        | Line Chart, Area Chart                        | Matplotlib, Seaborn, Plotly    |
# | **Categories Comparison**   | Bar Chart, Pie Chart, Count Plot              | Matplotlib, Seaborn, Plotly    |
# | **Distributions**           | Histogram, Box Plot, Violin Plot              | Seaborn, Matplotlib            |
# | **Relationships**           | Scatter Plot, Bubble Chart, Pair Plot         | Seaborn, Matplotlib, Plotly    |
# | **Parts of a Whole**        | Pie Chart, Donut Chart, Treemap               | Matplotlib, Plotly             |
# | **Correlations**            | Heatmap                                       | Seaborn                        |
# | **Geospatial Data**         | Choropleth Map, Scatter Map                   | Folium, Plotly, Geopandas      |
# | **Ranking & Ordering**      | Bar Chart, Lollipop Chart                     | Matplotlib, Seaborn            |
# | **Anomalies & Outliers**    | Box Plot, Scatter Plot                        | Seaborn, Matplotlib            |

# %% [markdown]
# Python has numerous libraries for data visualization here are a list of some of them; Matplotlib, Seaborn, Plotly, AltairBokeh, Geoplotlib, SciPy,etc.
#
# In this course we will be focusing on Matplotlib and Seaborn.  Matplotlib provides low-level control for creating static, animated, and interactive plots, while Seaborn offers high-level statistical visualizations with beautiful default styles.

# %% [markdown]
# ---

# %% [markdown]
# **MATPLOTLIB**

# %% [markdown]
# In Matplotlib, functions are used to create various visualizations like line plots, bar charts, scatter plots, etc. These functions are part of the pyplot module, which provides a MATLAB-like interface for plotting in Python. Below are some commonly used functions in Matplotlib and their descriptions.
#
# Please note: To avoid repetitions, we will deal with visualization fully in the Exploratory Data Analysis(EDA) class. And if you are curious, you can go through the maplot lib documentation and cheat sheet using the links below.
#
# [matplotlib cheat sheet](https://www.datacamp.com/cheat-sheet/matplotlib-cheat-sheet-plotting-in-python?utm_source=google&utm_medium=paid_search&utm_campaignid=19589720824&utm_adgroupid=152984014934&utm_device=c&utm_keyword=&utm_matchtype=&utm_network=g&utm_adpostion=&utm_creative=726015683694&utm_targetid=aud-2191467490030:dsa-2219652735736&utm_loc_interest_ms=&utm_loc_physical_ms=1010294&utm_content=DSA~blog~Python&utm_campaign=230119_1-sea~dsa~tofu_2-b2c_3-row-p2_4-prc_5-na_6-na_7-le_8-pdsh-go_9-nb-e_10-na_11-na-jan25&gad_source=1&gclid=Cj0KCQiAkoe9BhDYARIsAH85cDNKmX0Blrt0kckTHIMNhhxcD758s40F10vN24MVGy6k20lqbRZ90vUaAuLkEALw_wcB)
#
# [matplotlib documentation](https://matplotlib.org/3.5.3/gallery/index.html)
#
# [matplotlib tutorial pdf](https://drive.google.com/file/d/1D5X1FdrkQQ0a5qnjIwWY7-viZ2fc4w7S/view?usp=sharing)

# %% [markdown]
# Lets get started...
#
# * To use matplotlib library, you have to import it into your environment.
#
# ```
# import matplotlib.pyplot as plt
# ```
# #### Functions in Matplotlib
#
# * Creating your plots and charts
# ```
# plt.plot() # This is for line chart
# plt.bar() # This is used for bar chart
# plt.scatter() # This is used for scattered plots
# plt.hist() # This is used for plotting histogram
# plt.boxplot() # This is used for creating boxplots
# plt.pie() # This is creating pie charts
# plt.imshow() # This is used for creating heatmap(correlation)
# ```
#
# * customizing and setting your axis and labels
# ```
# plt.title() # the title of your plot
# plt.xlabel() # the x axis label
# plt.ylabel() # the y axis label
# plt.xlim() # limit for your x axis
# plt.ylim() # limit for your y axis
# plt.xticks() # the orientation of your x- values
# plt.yticks() # the orientation of your y- values
# plt.show()
# ```
#
# * Saving your plots
#
# ```
# plt.show()
# plt.savefig()
# ```
#
# * Adding legends to your plot
#
# ```
# plt.legend()
# plt.grid()
# ```
# * Add figures and Subplots functions
#
# ```
# plt.figure()
# plt.subplot()
# plt.subplots() # for multiple subplots
# plt.tight_layouts()
# ```

# %% [markdown]
# ---

# %% [markdown]
# **SEABORN**

# %% [markdown]
# Seaborn is built on Matplotlib and provides a high-level interface for drawing informative statistical graphics. It provides default themes make plots visually appealing.
# You can check out the seaborn documentation using the link below.
#
# [seaborn documentation](https://seaborn.pydata.org/tutorial.html)
#
# [seaborn cheatsheet](https://github.com/jramshur/Coding-Cheat-Sheets/blob/master/Python%20for%20Data%20Science%20-%20Cheat%20Sheet%20-%20Seaborn.pdf)

# %% [markdown]
# **How to use seaborn**
#
#
# ```
# sns.scatterplot()
# sns.lineplot()
# sns.barplot()
# sns.countplot()
# sns.histplot()
# sns.boxplot()
# sns.violinplot()
# sns.heatmap()
# sns.pairplot()
# sns.FacetGrit()
# sns.joinplot()
# sns.kdeplot()
# sns.regplot()
# ```

# %% [markdown]
# We will have our hands on practice during the EDA class.
#
#
# If you are curious, you can play around with these datasets;
#
# [Airline dataset](https://www.kaggle.com/datasets/saadharoon27/airlines-dataset)
#
# [Nigeria car sales](https://www.kaggle.com/datasets/oyekanmiolamilekan/nigeria-car-sales-dataset)
